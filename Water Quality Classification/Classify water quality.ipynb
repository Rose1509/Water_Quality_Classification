# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("waterquality.csv", "r", encoding="latin1") as f:
    for i, line in enumerate(f):
        if i >= 10 and i <= 20:  # peek around line 15
            print(i, line)
# Out:
# 10 Ó]Cbmg¤-è^]WªéAÜ\zS{0rL7Æ1ä~dÓ©ï^¼!fs/Ö¹×o`¯7¼T.­æiJT
#
# 11 §k­º«ýâ¦]8õ¨T»H»rxúW÷ðvåôLãøáLÃÙçåÍ¶×óåÓc|®ñäfMÎ·ÜÝMþYÎ¿vGX?
#
# 12 ¨9û¢Ë¼Õý¡ÿÿÿPK!ôõ;Yxl/_rels/workbook.xml.rels ¢( ¼ÏjÃ0Æï½Ñ}qn]uzØôºu`l%Mì`yòö39$ìz1HÂß÷C²¼?ü´
#
# 13 ûBOµ³²$V9]ÛJÀÇéõn´Z6Î¢	ÅíÍþ
#
# 14 â%2uG,ªX`Bè8'e°¸m¬Î·2ÄÐW¼ê,+äyn¹ÿ«ÅLµÔ`§¾Îÿk»²¬¾8õÙ¢
#
# 15 ,ø·óg2!J_a0¦M_y\FÉF=YÛ	fL-AäWîH¾]&[Ù®	CFzÔïÁÇU iD³ôÌÃª0¡oâæ¯xÉþ~Mû÷'÷!äÃ9ÎÏ>âÿÿPK!}ó(xmã®
#
# 16 xl/worksheets/sheet1.xmlT[o0~´ÿüÀ@HBª©Uµ¾LÕºË³cLbãÌvnöß{l.-eÏÁøûÎíùÝQTÞ)Íe#ìÈc5¯W9úþíq4E6¤.H%k£ÓènññÃü ÕF¯30Ô:Gkc¶Yhºfh_nY
#
# 17 OJ©1p«VÞ*F
#
# 18 UaÂkÔ0d,KNÙ¤;ÁjÓ(Vùë5ßêMÐ!t¨Ín;¢RlbÉ+nNyfO«Z*²¬ î#õ
#
# 19 þqÆí_E*©ei|`¯Ë³ÐéºþA48	Ûs;À3Uô¾ð¸çÎdñ;ÉÒÌ¶Ke;^äèOØþF`±]ÂóÒ=ûóÃmUbe>áìÇiÅÜIèg}á{,_XÅ¨a#ï·â;½éøâödÕlZ/¥ÜX²'X;PÃ÷ìUpú>áK\H"è³¸ô»îW°ì*óU>3¾ZH-ñèTV¦ íÇÊ
#
# 20 8`õ·o=ðÂ¬ÁfÒ6Rül7ZX¹9Ø§~Ga#èÂ

# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
import pandas as pd

df = pd.read_excel("waterquality.csv")  # yes, even if it has .csv extension
df.head()
# Out:
#    Stationcode                                 Locations        Lat  \
# 0         1001                        BEAS AT U/S MANALI  32.244947
# 1         1002                          BEAS AT D/S KULU  31.960582
# 2         1003                           BEAS AT D/S AUT  26.887893
# 3         1004                    BEAS AT U/S PANDON DAM  47.351943
# 4         1005  BEAS AT EXIT OF TUNNEL DEHAL POWER HOUSE  25.992786
#
#          Lon Capitalcity             State  Temperature   D.O   pH  \
# 0  77.191080      Shimla  HIMACHAL PRADESH          9.0   9.0  8.0
# 1  77.114009      Shimla  HIMACHAL PRADESH         10.0   9.0  8.0
# 2  75.811484      Shimla  HIMACHAL PRADESH         11.0   9.0  8.0
# 3  19.633621      Shimla  HIMACHAL PRADESH         13.0   9.0  8.0
# 4  91.826111      Shimla  HIMACHAL PRADESH         14.0  10.0  8.0
#
#   Conductivity  B.O.D Nitrate Fecalcaliform  Totalcaliform class
# 0           85    0.1     0.2           106          397.0   yes
# ...
